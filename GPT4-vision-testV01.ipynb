# %% [markdown]
# https://learn.microsoft.com/nl-nl/azure/ai-services/openai/how-to/gpt-with-vision?tabs=python

# %% [raw]
# micromamba create -n multimodal-azure-env -c conda-forge python=3.12 jupyter
#
# micromamba activate multimodal-azure-env
#
# pip install pdf2image requests openai python-dotenv

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
### needs to instal pip openai
import os
import openai


api_base = 'https://chatbotters.openai.azure.com/' # your endpoint should look like the following https://YOUR_RESOURCE_NAME.openai.azure.com/
api_key = "deployment_name = 'GPT4Vision'
api_version = '2024-02-15-preview' # this might change in the future

client = openai.AzureOpenAI(
    api_key=api_key,  
    api_version=api_version,
    base_url=f"{api_base}openai/deployments/{deployment_name}",
)
